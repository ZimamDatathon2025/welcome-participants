# %% [markdown]
# # Zimam Datathon 2025

# %% [markdown]
# ## Welcome Package for Participants

# %% [markdown]
# ![GCC 7th.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# *6-8 Nov 2025* <br/>
# ***November 6, 2025*** | Jumeirah Emirates Towers <br />
# ***November 7-8, 2025*** | Center for Innovation & Technology, Dubai Health <br>

# %% [markdown]
# ## Schedule
#
# ### Day 1 - Thursday, November 6
#
# | **Time** | **Activity** |
# |----------|--------------|
# | 3:00p - 3:15p | Welcome & Opening Remarks<br>Overview of Datathon (Structure and Expectations)<br>*Lama Nazer, King Hussein Cancer Center* |
# | 3:15p - 3:30p | Overview of the Datasets and Tools<br>*Ian Wong, Duke University* |
# | 3:30p - 3:50p | Bias in Artificial Intelligence and Strategies to Mitigate<br>*Lama Nazer, King Hussein Cancer Center* |
# | 3:50p - 4:10p | Healthcare AI and the Agentic Future<br>*Steve Bethke, Mayo Clinic Platform* |
# | 4:10p - 4:30p | Beyond Accuracy: Building ML Pipelines that See Everyone<br>*Aya El Mir, NYU Abu Dhabi* |
# | 4:30p - 5:00p | Team Distribution and Introductions<br>Set-up Access to Datasets<br>*Chrystinne Fernandes, MIT* |
# | 5:00p | Closing & End of Day 1 |
#
# ### Days 2 & 3 - Friday, November 7 & Saturday, November 8
#
# | Day 2 - Friday, November 7 | | Day 3 - Saturday, November 8 | |
# |----------------------------|---------------------------|------------------------------|---------------------------|
# | **Time** | **Activity** | **Time** | **Activity** |
# | 9:00a - 9:15a | Briefing Session | 9:00a - 9:15a | Briefing Session |
# | 9:15a - 9:30a | Practical Tips and Tools<br>*Rajna Fani & Rafi Al Attrach, University of Munich* | 9:15a - 11:30a | 🔧 Datathon Teamwork |
# | 9:30a - 11:00a | 🔧 Datathon Teamwork | 11:30a - 12:00p | ▶️ Checkpoint 3<br>*Dataset cleaned, analysis started; discuss initial findings* |
# | 11:00a - 11:30a | ▶️ Checkpoint 1<br>*Discuss refined team question with rationale and clinical implications* | 12:00p - 12:30p | 🔧 Datathon Teamwork |
# | 11:30a - 12:30p | 🔧 Datathon Teamwork | 12:30p - 2:00p | 🍕 Lunch & Prayer Time |
# | 12:30p - 1:30p | 🍕 Lunch & Prayer Time | 2:00p - 3:00p | ▶️ Checkpoint 4<br>*Discuss your presentation* |
# | 1:30p - 2:30p | 🔧 Datathon Teamwork | 3:00p - 4:00p | 🖊️ Team Presentations<br>*5-min: research question, analytical methods,<br> findings, limitations, clinical implications* |
# | 2:30p - 3:00p | ▶️ Checkpoint 2<br>*Discuss analytical plan, variables/features, and sources of bias* | 4:00p - 4:30p | 📝 Judging |
# | 3:00p - 3:30p | 🔧 Datathon Teamwork | 4:30p | 🎉 Announcement of Winners<br>Closing of Day 3 |
# | 3:30p - 4:30p | 📝 Team Presentations<br>*5-min: research question, rationale, clinical implications, analytical plan/sources of bias* | | |
# | 4:30p | Closing & End of Day 2 | | |
#
#
# Mentors have 5 minutes per table during the checkpoint. Please expect mentors to swing by. Don't feel pressured to keep them for the full 5 minutes. If you don't have any questions for this mentor, please feel free to let them move on.
#
# Please feel free to flag down mentors during the Teamwork sessions.
#
# **Fri, 7 Nov**
#
# By Checkpoint 1 (11:00a), please be ready to discuss your refined team question with rationale and clinical implications.
#
# By Checkpoint 2 (2:30p), please be ready to discuss your analytical plan and variables/features you plan to evaluate. Address sources of bias and include rationale for your plan.
#
# Team Presentations (3:30p): 5-minute presentation of research question, rationale, clinical implications, and analytical plan/sources of bias.
#
#
# **Sat, 8 Nov**
#
# By Checkpoint 3 (11:30a), you should have your dataset cleaned and analysis started. Be ready to discuss your initial findings and analysis.
#
# By Checkpoint 4 (2:00p), please be ready to discuss your presentation.
#
# Team Presentations (3:00p): 5-minute presentation of research question, analytical methods, findings, limitations, and clinical implications.
#
#
#
# ---
#
# ## What to Bring?
# Your Laptop, if possible. Data will be made available in the cloud. We'll be using Colab Notebooks, and everything can be done in the cloud. If you prefer, you can also use your local machine.
#
# ## What are we looking for in the participants?
# There will be 8 teams of approximately 6-8 participants:
# - half data science
# - half clinical
#
# At least one of the data science participants at each table will have had experience at a prior datathon and/or substantial experience with a PhysioNet dataset and this kind of EHR data analysis. <br>
#
# Everyone attending is interested in EHR data and data science. This is a unique situation where everyone has a pre-selected interest. All the clinical participants have an interest in data science. All the data science participants have an interest in medicine. <br>
#
# At the very least, the **clinical participants** should shape the meaning of the question (especially making sure that the problem is defined in a clinically relevant fashion), lend context to the clinical data, and shape the results. <br>
#
# The **data science participants** should be ready to learn about the datasets, understand how to effectively extract the relevant data, wrangle data, and analyze the results. <br>
# - _Note:_ Some (but not necessarily all) of the clinical participants might want to stretch their data science aspects. Consider supporting their learning here. <br>
#
# Neither side is more important; the interplay of both is critical to effective analysis. We want participants to learn that this is a team science and we really need to engage people with different perspectives and from different areas of expertise to tackle such complex questions.
